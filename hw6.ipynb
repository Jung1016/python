# %% [markdown]
# <a href="https://colab.research.google.com/github/Jung1016/python/blob/main/hw6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return x**2 + np.sin(3*x+7)

x = np.arange(0, 2, 0.1)
y = f(x)

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return (1/2)*a**2 + (1/3)*b**3 + 4*np.cos(b)

def grad_f(a,b): # gradient
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] # to store all thetas
	theta = theta0     # initial values for thetas
	# main loop by iterations:
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) #함수 f(x,y)의 gradient
		# update parameters:
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-2, 2], iters =30, alpha = 0.1)

fig = plt.figure(figsize=(15, 10))
ax = fig.gca(projection='3d')
a = np.arange(-2, 2, 0.25)
b = np.arange(-2, 2, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
## c= 0 ## 최소값을 찾기 위한 부분
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

plt.show()
# Out:
# [3.00207932 2.61259939 2.30291045 2.05319297 1.85115865 1.68756205
#  1.55506003 1.44773588 1.36080386 1.29038905 1.23335307 1.18715394
#  1.14973265 1.1194214  1.09486929 1.07498208 1.05887344 1.04582544
#  1.03525656 1.02669577 1.01976153 1.01414479 1.00959524 1.0059101
#  1.00292513 1.00050731 0.99854888 0.99696255 0.99567762 0.99463683
#  0.99379378]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

targetUrl = 'https://raw.githubusercontent.com/Jung1016/python/main/caffeine.csv'

Data_set = pd.read_csv(targetUrl, sep=',')

print(Data_set.shape)

sn.set_theme()
sn.set(rc = {"figure.dpi":300})
sn.set(rc = {"figure.figsize":(6,3)})

sn.scatterplot(x = "Caffeine (mg)", y = "Calories", data = Data_set, hue = 'type')
# Out:
# (610, 5)

# %%
sn.histplot(y = "Calories", data = Data_set)

# %%
sn.histplot(x = "Caffeine (mg)", data = Data_set)

# %%
sn.histplot(x = "Calories", data = Data_set, kde = "True")

# %%
sn.histplot(x = "Calories", data = Data_set, hue = "type")

# %%
sn.barplot(x = "type", y = "Caffeine (mg)", data = Data_set)

# %%
sn.boxplot(x = "type", y = "Calories", data = Data_set)
